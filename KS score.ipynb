# %%
import pandas as pd
import numpy as np

# %%
prediction = pd.read_csv('y_test_for_ks_score_check.csv')

# %%
prediction.head()
# Out:
#    id  probability
# 0   2     0.125117
# 1   5     0.085525
# 2   6     0.416817
# 3   7     0.106001
# 4   8     0.072467

# %%
prediction.describe()
# Out:
#                  id   probability
# count  47884.000000  47884.000000
# mean   29843.736238      0.128899
# std    15324.959974      0.121784
# min        2.000000      0.002117
# 25%    17121.250000      0.037602
# 50%    30418.500000      0.094481
# 75%    43014.250000      0.166068
# max    55596.000000      0.912234

# %%
prediction_sorted = prediction.sort(columns='probability')
# Out:
# /Users/wakemeup/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
prediction_sorted.reindex()
# Out:
#           id  probability
# 34220  41248     0.002117
# 27510  34118     0.002576
# 12632  17891     0.002635
# 26184  32758     0.002786
# 41789  49182     0.002830
# 45519  53101     0.002886
# 42206  49629     0.003067
# 23571  30027     0.003112
# 7474   11717     0.003424
# 44822  52359     0.003488
# 24658  31166     0.003488
# 11551  16602     0.003491
# 22050  28422     0.003598
# 44565  52100     0.003816
# 17555  23550     0.004025
# 43501  50985     0.004112
# 24176  30655     0.004189
# 28408  35088     0.004201
# 10179  15055     0.004352
# 7742   12061     0.004369
# 38762  46009     0.004381
# 24234  30722     0.004446
# 18675  24738     0.004584
# 41226  48581     0.004665
# 9571   14314     0.004668
# 10838  15798     0.004673
# 21003  27271     0.004702
# 12117  17273     0.004717
# 14044  19518     0.004724
# 16331  22190     0.004764
# ...      ...          ...
# 38330  45542     0.768577
# 37823  45024     0.768577
# 26412  32986     0.787656
# ...

# %%
prediction_sorted.head()
# Out:
#           id  probability
# 34220  41248     0.002117
# 27510  34118     0.002576
# 12632  17891     0.002635
# 26184  32758     0.002786
# 41789  49182     0.002830
